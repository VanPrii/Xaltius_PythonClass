# %%
#getting and knowing your data
#step 1: import necessary libraries
import pandas as pd
import numpy as np

# %%
#for mac users to import links
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
#step 2: import dataset from the URL and to a variable
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv' #url as variable only
chipo = pd.read_csv(url, sep='\t') #chipo as data set name, sep - separate, convert tsv into csv
chipo
#should appear in table format
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#step 3: see the first 10 entries
#5 as default value, included in interview
chipo.head(10)
# Out:
#    order_id  quantity                              item_name
# 0         1         1           Chips and Fresh Tomato Salsa  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 4: what is the number of observations in the dataset?
#observations - total entries of data

#solution 1
chipo.shape[0] #ID 0
# Out:
# 4622

# %%
#step 4, solution 2
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#step 5: what numbers of columns in dataset?
#0 means row, 1 means cols in shape
chipo.shape[1]
# Out:
# 5

# %%
#step 6: print all the name of your columns
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 7: which is the most ordered item?
#group by function
#5 display entries as default value

c = chipo.groupby('item_name') #item_name - column name
c = c.sum()
c = c.sort_values(['quantity'], ascending=False) #item mostly ordered, default in ascending
c.head(1) #display only first item, the most ordered
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761  \
#
#                                              choice_description
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  \
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %%
#most ordered choice description
d = chipo.groupby('choice_description') #column name
d = d.sum()
d = d.sort_values(['quantity'], ascending=False) #item mostly ordered, default in ascending
d.head()
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159  \
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
#
#                                                                                             item_name
# choice_description
# [Diet Coke]                                         Canned SodaCanned SodaCanned Soda6 Pack Soft D...  \
# [Coke]                                              Canned Soft DrinkCanned Soft DrinkCanned Soft ...
# [Sprite]                                            Canned SodaCanned SodaCanned Soft Drink6 Pack ...
# ...

# %%
#check total number of item ordered
total = chipo.quantity.sum()
total
# Out:
# 4972
