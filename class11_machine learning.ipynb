# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
#for mac users to import links
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pip install scikit-learn
#ML library, classification, regression, clustering algo - k-means
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 9.4 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 9.0 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 10.0 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#create a custom dataset with make_blobs and plot it
X,y = make_blobs(n_samples=500,n_features=2,centers=3,random_state=23)
#default sample data: 100
#n_features - 
#centers - 
#random state - data splitting
fig = plt.figure(0) #start from the x-axis
plt.grid(True)
plt.scatter(X[:,0],X[:,1]) #first x - for x axis, second x - for y axis, 2D array
plt.show()

# %%
#plot the random initialize center with data points
#need to use for loop

#K-means clustering
import pandas as pd
from sklearn import datasets #no need to go with csv, it will automatically load the data

# %%
#load iris dataset
iris = datasets.load_iris() #dictionary
iris_df = pd.DataFrame(iris.data,columns = iris.feature_names) #pd.DataFrame - converting dictionary to dataframe
iris_df.head()
#sepal - 
#petal -
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
